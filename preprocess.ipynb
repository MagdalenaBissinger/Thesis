# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Merging both files
final_df_1 = pd.read_csv("Final_dataset_v1.csv")
final_df_1 = final_df_1.drop(columns = ["Unnamed: 0.2", "Unnamed: 0.1", "Unnamed: 0"])
final_df_2 = pd.read_csv("Final_dataset.csv")

url_status = pd.concat([final_df_2, final_df_1], ignore_index=True)
url_status.drop_duplicates(subset = "URL")
url_status.to_csv("Final_dataset_v2.csv")

# %%
final_df_2 = pd.read_csv("Final_dataset_v2.csv")
final_df_2 = final_df_2.drop(columns = "Unnamed: 0")
final_df_2.head(5)
# Out:
#       FILENAME                           URL  URLLength                Domain  \
# 0  515489.html  https://www.socialpolicy.org         27  www.socialpolicy.org
# 1   53440.html     https://www.bikeseoul.com         24     www.bikeseoul.com
# 2   91992.html       https://www.radware.com         22       www.radware.com
# 3  571426.html   https://www.gunsmokenet.com         26   www.gunsmokenet.com
# 4  178925.html       https://www.mro.nmt.edu         22       www.mro.nmt.edu
#
#    DomainLength  IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 0            20           0  org               100.0              1.000000
# 1            17           0  com               100.0              1.000000
# 2            15           0  com               100.0              1.000000
# 3            19           0  com               100.0              1.000000
# 4            15           0  edu               100.0              0.571429
#
# ...

# %%
final_df_2.describe()
# Out:
#          URLLength  DomainLength  IsDomainIP  URLSimilarityIndex  \
# count  5323.000000   5323.000000      5323.0         5323.000000
# mean     29.839564     19.437159         0.0           84.195775
# std      22.107136      5.966739         0.0           24.126499
# min      14.000000      6.000000         0.0            2.702249
# 25%      23.000000     16.000000         0.0           70.985491
# 50%      26.000000     19.000000         0.0          100.000000
# 75%      30.000000     23.000000         0.0          100.000000
# max     495.000000     73.000000         0.0          100.000000
#
#        CharContinuationRate  TLDLegitimateProb  URLCharProb    TLDLength  \
# count           5323.000000        5323.000000  5323.000000  5323.000000
# mean               0.901841           0.280808     0.057827     2.801616
# std                0.174764           0.250013     0.009554     0.606632
# min                0.205882           0.000003     0.006982     2.000000
# ...

# %%
#final_df.info()

# %%
#Checking duplicates
#final_df[final_df.duplicated()]

# %%
# Checking for duplicates
duplicates = final_df_2.duplicated().sum()
duplicates
# Out:
# 0

# %%
# Checking for missing values
missing_content = final_df_2["Page_Content"].isnull().sum().sum()
missing_content

#Additional check
missing_content_df = final_df_2[final_df_2["Page_Content"].isnull()]
missing_content_df.head(10)

#Drop rows with missing content
final_df = final_df_2.dropna(subset =["Page_Content"])

# %%
# Checking for missing values
missing_headings = final_df["Headings"].isnull().sum().sum()
missing_headings
# Out:
# 609

# %%
# Checking for missing values
missing_meta = final_df["Meta_Description"].isnull().sum().sum()
missing_meta
# Out:
# 1999

# %%
final_df_2["FILENAME"] = final_df_2["FILENAME"].astype(str)

# %%
final_df_2 = final_df_2.drop_duplicates()

# %%
final_df_2["label"].value_counts()
# Out:
# label
# 1    3181
# 0    1095
# Name: count, dtype: int64
